# %%
import pandas as pd
df = pd.read_csv('Results/results.csv')
df
# Out:
#                       epoch           train/box_loss           train/cls_loss  \
# 0                         1                  1.90940                  1.91140
# 1                         2                  1.76880                  1.50190
# 2                         3                  1.75410                  1.47790
# 3                         4                  1.72760                  1.43970
# 4                         5                  1.69920                  1.37010
# ..                      ...                      ...                      ...
# 95                       96                  0.95685                  0.49123
# 96                       97                  0.96214                  0.49277
# 97                       98                  0.94473                  0.48071
# 98                       99                  0.94097                  0.48658
# 99                      100                  0.94196                  0.48633
#
#              train/dfl_loss     metrics/precision(B)        metrics/recall(B)  \
# 0                   1.50880                  0.52569                  0.46981
# 1                   1.41360                  0.58653                  0.43682
# 2                   1.41170                  0.54068                  0.56685
# 3                   1.39470                  0.54671                  0.61133
# 4                   1.38380                  0.63525                  0.66941
# ..                      ...                      ...                      ...
# 95                  1.00100                  0.87916                  0.79835
# 96                  1.00430                  0.85881                  0.82065
# 97                  0.99536                  0.87266                  0.81087
# 98                  0.99875                  0.87620                  0.80978
# 99                  0.99347                  0.85343                  0.81793
#
#            metrics/mAP50(B)      metrics/mAP50-95(B)             val/box_loss  \
# 0                   0.44023                  0.18547                   2.0189
# 1                   0.43761                  0.12405                   2.6324
# 2                   0.54151                  0.19020                   2.2730
# 3                   0.59527                  0.25287                   1.9045
# 4                   0.64017                  0.24183                   2.1393
# ..                      ...                      ...                      ...
# 95                  0.86862                  0.43555                   1.7135
# 96                  0.87983                  0.44565                   1.7098
# 97                  0.88114                  0.44451                   1.7024
# 98                  0.87991                  0.44525                   1.7011
# 99                  0.87616                  0.44390                   1.6939
#
#                val/cls_loss             val/dfl_loss                   lr/pg0  \
# 0                   1.72050                   1.5183                 0.000553
# 1                   1.79620                   2.0021                 0.001098
# 2                   1.56240                   1.7211                 0.001631
# 3                   1.44660                   1.5022                 0.001618
# 4                   1.36350                   1.6429                 0.001618
# ..                      ...                      ...                      ...
# 95                  0.81485                   1.4050                 0.000116
# 96                  0.80127                   1.3970                 0.000099
# 97                  0.80443                   1.3938                 0.000083
# 98                  0.80372                   1.3969                 0.000066
# 99                  0.80741                   1.3909                 0.000050
#
#                      lr/pg1                   lr/pg2
# 0                  0.000553                 0.000553
# 1                  0.001098                 0.001098
# 2                  0.001631                 0.001631
# 3                  0.001618                 0.001618
# 4                  0.001618                 0.001618
# ..                      ...                      ...
# 95                 0.000116                 0.000116
# 96                 0.000099                 0.000099
# 97                 0.000083                 0.000083
# 98                 0.000066                 0.000066
# 99                 0.000050                 0.000050
#
# [100 rows x 14 columns]

# %%
import matplotlib.pyplot as plt
from pandas.table.plotting import table
ax = plt.subplot(111, frame_on=False) # no visible frame
ax.xaxis.set_visible(False)  # hide the x axis
ax.yaxis.set_visible(False)  # hide the y axis

table(ax, df)  # where df is your data frame

plt.savefig('mytable.png')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import matplotlib.pyplot as plt
# ----> 2 from pandas.table.plotting import table
#       3 ax = plt.subplot(111, frame_on=False) # no visible frame
#       4 ax.xaxis.set_visible(False)  # hide the x axis
#
# ModuleNotFoundError: No module named 'pandas.table'
